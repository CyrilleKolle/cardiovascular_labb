# %%
import pandas as pd

df = pd.read_csv('../data/prediction.csv')

df
# Out:
#    prediction     predicted_result actual_result
# 0   Id: 94269  probability class 0    positive 1
# 1   Id: 25632  probability class 1    positive 1
# 2     Id: 049  probability class 1    negative 0
# 3   Id: 13397  probability class 1    negative 0
# 4   Id: 58693  probability class 0    positive 1
# ..        ...                  ...           ...
# 95  Id: 64453  probability class 0    positive 1
# 96  Id: 38683  probability class 1    positive 1
# 97  Id: 53785  probability class 0    negative 0
# 98  Id: 61786  probability class 0    negative 0
# 99  Id: 10711  probability class 1    positive 1
#
# [100 rows x 3 columns]
